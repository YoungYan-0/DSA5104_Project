# %%
import pandas as pd
import pymongo
import csv

# %%
client = pymongo.MongoClient("localhost:27017")
airbnbDB = client["Airbnb"]

# %% [markdown]
# ## Load Customers

# %%
customers = pd.read_csv('customer.csv', delimiter='|')
customers['_id'] = customers['cid']
customers=customers.drop(columns=['cid'])
customers
# Out:
#              name        _id
# 0             Kim  273940743
# 1          Oliver  143251478
# 2           Doris  288635322
# 3            Yang  163790201
# 4           Kunat  317920443
# ...           ...        ...
# 210362    Pawarit  230287718
# 210363    ปฐมพงษ์  422917562
# 210364    Michael    9395774
# 210365      Xylis  301320803
# 210366  Premkamon  453549937
#
# [210367 rows x 2 columns]

# %%
customerCollection = airbnbDB["Customer"]
customerCollection.insert_many(customers.to_dict('records'))

# %% [markdown]
# ## Load Hosts

# %%
hosts = pd.read_csv('host.csv', delimiter=',')
hosts['_id'] = hosts['hid']
hosts['is_super_host'] = hosts['is_super_host'].astype(bool)
hosts['email_verified'] = hosts['email_verified'].astype(bool)
hosts['phone_verified'] = hosts['phone_verified'].astype(bool)
hosts['work_email_verified'] = hosts['work_email_verified'].astype(bool)
hosts['identity_verified'] = hosts['identity_verified'].astype(bool)
hosts = hosts.drop(columns=['hid'])
hosts.head()
# Out:
#      name       since                   location  \
# 0   Fawad  2013-01-11  Siālkot, Punjab, Pakistan
# 1  Supika  2016-10-23                         TH
# 2  Noodee  2019-10-21                         TH
# 3    Krit  2019-04-19          Bangkok, Thailand
# 4   เบนซ์  2018-01-11  Lak Si, Bangkok, Thailand
#
#                                          description       response_time  \
# 0  I am tourist, would love to visit different co...      within an hour
# 1                                                NaN                 NaN
# 2                                                NaN  a few days or more
# 3                                                NaN                 NaN
# 4    ผมเปํ็นคนมีอัธยาศัยดี ไม่สูบบุหรี่ ไม่ดื่มเหล้า                 NaN
#
#    response_rate  acceptance  is_super_host neighbourhood  email_verified  \
# 0            1.0         0.0          False           NaN            True
# 1            0.0         0.0          False           NaN           False
# 2            0.0         0.0          False           NaN            True
# 3            0.0         1.0          False           NaN            True
# 4            0.0         0.0          False           NaN            True
#
#    phone_verified  work_email_verified  identity_verified  \
# 0            True                False              False
# 1            True                False              False
# 2            True                False               True
# 3            True                False               True
# 4            True                False              False
#
#                                              picture  \
# 0  https://a0.muscache.com/im/users/4663219/profi...
# 1  https://a0.muscache.com/im/pictures/user/abac9...
# 2  https://a0.muscache.com/im/pictures/user/3ed3b...
# 3  https://a0.muscache.com/im/pictures/user/afaec...
# 4  https://a0.muscache.com/im/pictures/user/cc8e7...
#
#                                            thumbnail  \
# 0  https://a0.muscache.com/im/users/4663219/profi...
# 1  https://a0.muscache.com/im/pictures/user/abac9...
# 2  https://a0.muscache.com/im/pictures/user/3ed3b...
# 3  https://a0.muscache.com/im/pictures/user/afaec...
# 4  https://a0.muscache.com/im/pictures/user/cc8e7...
#
#                                            url        _id
# 0    https://www.airbnb.com/users/show/4663219    4663219
# 1  https://www.airbnb.com/users/show/100840975  100840975
# 2  https://www.airbnb.com/users/show/303573998  303573998
# 3  https://www.airbnb.com/users/show/256747704  256747704
# 4  https://www.airbnb.com/users/show/167136634  167136634

# %%
hostCollection = airbnbDB["Host"]
hostCollection.insert_many(hosts.to_dict('records'))

# %% [markdown]
# ## Load Listings

# %%
listings = pd.read_csv('listing.csv', delimiter='|')
listings['_id'] = listings['lid']
listings = listings.drop(columns=['lid'])

listings.head()
# Out:
#                                              name  \
# 0   Furnished 1 bedroom condo with beautiful view
# 1                        Akesin place ngamwongwan
# 2  IMPACT Thunder Dome Muangthong ND condo ( C1 )
# 3                       Popular Condo Near IMPACT
# 4                                       บ้านเบนซ์
#
#                                          description  neighbourhood  \
# 0  🏢Condo For rent: Lumpini Ville Nakhon In-River...       Bang Sue
# 1  ที่ของฉันใกล้กับร้านอาหารและของกิน และ ขนส่งสา...       Bang Sue
# 2                                                NaN         Lak Si
# 3  คอนโดเมืองทองอยู่ในบริเวณเดียวกับศูนย์แสดงสินค...         Lak Si
# 4  เป็นหมู่บ้านขนาดใหญ่มีหลายเฟส บ้านเป็นทาวน์โฮม...  Khlong Sam Wa
#
#                                             overview       host   latitude  \
# 0                            Its in Lumpini building    4663219  13.843799
# 1                                                NaN  100840975  13.858900
# 2  IMPACT ศูนย์แสดงสินค้า  550 m<br />IMPACT Chal...  303573998  13.907330
# 3  คอนโดเมืองทองอยู่ในบริเวณเดียวกับศูนย์แสดงสินค...  256747704  13.907680
# 4                                                NaN  167136634  13.925490
#
#     longitude                property_type  accommodates       bathrooms  ...  \
# 0  100.512203                 Entire condo             2          1 bath  ...
# 1  100.527390  Private room in rental unit             2          1 bath  ...
# 2  100.550940        Private room in condo             2          1 bath  ...
# 3  100.554060        Private room in condo             2  1 private bath  ...
# 4  100.720380         Private room in home             2  2 shared baths  ...
#
#    beds                                          amenities  \
# 0   1.0  ["Kitchen", "Air conditioning", "Free parking ...
# 1   1.0  ["Wifi", "Kitchen", "Washer", "Air conditionin...
# 2   1.0  ["Shampoo", "Kitchen", "Air conditioning", "Ha...
# 3   1.0  ["Shampoo", "Air conditioning", "TV", "Hangers...
# 4   1.0  ["Shampoo", "Kitchen", "Air conditioning", "Fr...
#
#   review_scores_rating  review_scores_accuracy  review_scores_cleanliness  \
# 0                 0.00                     0.0                        0.0
# 1                 0.00                     0.0                        0.0
# 2                 4.67                     5.0                        5.0
# 3                 4.50                     5.0                        5.0
# 4                 0.00                     0.0                        0.0
#
#    review_scores_checkin  review_scores_communication  review_scores_location  \
# 0                    0.0                          0.0                    0.00
# 1                    0.0                          0.0                    0.00
# 2                    5.0                          5.0                    4.67
# 3                    5.0                          4.0                    4.50
# 4                    0.0                          0.0                    0.00
#
#    review_scores_value                 _id
# 0                 0.00  645048906856594097
# 1                 0.00            15636062
# 2                 4.67            39544047
# 3                 4.00            34002624
# 4                 0.00            22678899
#
# [5 rows x 21 columns]

# %%
listingCollection = airbnbDB["Listing"]
listingCollection.insert_many(listings.to_dict('records'))

# %% [markdown]
# ## Load Calendar

# %%
# calendars = pd.read_csv('calendar.csv', delimiter='|')
# calendars['availability'] = calendars['availability'].astype(bool)
# calendars['calendar'] = calendars.to_dict('records')
# calendars = calendars[['property', 'calendar']]
# calendars = calendars.rename(columns={'property':'_id'})
# calendars = pd.DataFrame(calendars.groupby('_id')['calendar'].apply(list))
# # calendars.drop_duplicates(subset=['_id'], inplace=True)

# calendars.head()

# listings = listings.merge(calendars, on='_id')
# listings.head()

# %%
calendars = pd.read_csv('calendar.csv', delimiter='|')
calendars['availability'] = calendars['availability'].astype(bool)

calendars
# Out:
#                    property        date  availability  min_nights  max_nights  \
# 0        645048906856594097  2022-06-20          True         1.0       365.0
# 1        645048906856594097  2022-06-21          True         1.0       365.0
# 2        645048906856594097  2022-06-22          True         1.0       365.0
# 3        645048906856594097  2022-06-23          True         1.0       365.0
# 4        645048906856594097  2022-06-24          True         1.0       365.0
# ...                     ...         ...           ...         ...         ...
# 6231640  603257031288352002  2023-06-15          True         1.0      1125.0
# 6231641  603257031288352002  2023-06-16          True         1.0      1125.0
# 6231642  603257031288352002  2023-06-17          True         1.0      1125.0
# 6231643  603257031288352002  2023-06-18          True         1.0      1125.0
# 6231644  603257031288352002  2023-06-19          True         1.0      1125.0
#
#          price  adjusted_price
# 0        890.0           890.0
# 1        890.0           890.0
# 2        890.0           890.0
# 3        890.0           890.0
# 4        890.0           890.0
# ...        ...             ...
# 6231640  800.0           800.0
# 6231641  800.0           800.0
# 6231642  800.0           800.0
# 6231643  800.0           800.0
# 6231644  800.0           800.0
#
# [6231645 rows x 7 columns]

# %%
calendarCollection = airbnbDB['Calendar']
calendarCollection.insert_many(calendars.to_dict('records'))

# %% [markdown]
# ## Load Transactions

# %%
transactions = pd.read_csv('transactions.csv', delimiter='|')
transactions.rename(columns={'tid':'_id'}, inplace=True)

transactions.head()
# Out:
#          _id   customer  property  start_date    end_date  total_price  \
# 0  564106023  273940743  39544047  2019-11-09  2019-11-13       2400.0
# 1  566622127  143251478  39544047  2019-11-09  2019-11-10        600.0
# 2  568138380  288635322  39544047  2019-11-14  2019-11-20       3600.0
# 3  568816394  163790201  39544047  2019-11-18  2019-11-21       1800.0
# 4  597651173  317920443  39544047  2020-01-12  2020-01-15       1800.0
#
#                                               review
# 0  Good communication, basic and clean accommodation
# 1  Good, clean, cheap accomodation in proximity t...
# 2  A nice room, very close to impact arena, also ...
# 3  The landlord sister is really kind and lovely....
# 4  The room was very new, cleand and well funishe...

# %%
transactionCollection = airbnbDB['Transaction']
transactionCollection.insert_many(transactions.to_dict('records'))
